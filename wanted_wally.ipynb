# %% [markdown]
# **Wanted: Wally** - This notebook demonstrates training and applying the CNN.

# %%
from wally_cnn import (
    package_dataset,
    run_training,
    run_hypothesis)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# hdf5 is not supported on this machine (please install/reinstall h5py for optimal experience)
# Scipy not supported!

# %%
training_data = package_dataset()
# Out:
# 100%|██████████| 21610/21610 [00:15<00:00, 1353.68it/s]

# %%
run_training(training_data)
# Out:
# Training Step: 971  | total loss: 0.01985 | time: 118.060s
# | Adam | epoch: 003 | loss: 0.01985 - acc: 0.9941 -- iter: 19904/21110

# %%
image = run_hypothesis(filepath='wally_hypothesis.jpg')
# Out:
# INFO:tensorflow:Restoring parameters from /Users/craigw/src/wally/wanted_wally.model
# 100%|██████████| 4698/4698 [00:21<00:00, 215.21it/s]

# %%
image.save('wally_hypothesis_highlighted.jpg')
plt.imshow(image)
